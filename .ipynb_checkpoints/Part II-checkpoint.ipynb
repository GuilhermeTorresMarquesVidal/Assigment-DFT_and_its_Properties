# %% [markdown]
# ## Libraries

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.ticker import NullLocator
import matplotlib.image as mpimg
from scipy.fft import fft2, ifft2
from scipy.ndimage import rotate
from Contents.FFT import fft2d, ifft2d

# %% [markdown]
# ## Read image

# %%
img = mpimg.imread('Images/cameraman.tif')

# %% [markdown]
# ## Plotting image

# %%
fig, ax = plt.subplots(figsize = (8,6))

ax.imshow(img, cmap = 'gray')

plt.gca().xaxis.set_major_locator(NullLocator())
plt.gca().yaxis.set_major_locator(NullLocator())

# %% [markdown]
# ## DFT scipy

# %%
img_DFT = fft2(img)

# %% [markdown]
# ## inverse DFT manually

# %%
img_iDFT_manually = ifft2d(img_DFT)

# %% [markdown]
# ## Plotting image with inverse DFT manually

# %%
fig, ax = plt.subplots(figsize = (8,6))

ax.imshow(img_iDFT_manually.real, cmap = 'gray')

plt.gca().xaxis.set_major_locator(NullLocator())
plt.gca().yaxis.set_major_locator(NullLocator())

# %% [markdown]
# ## DFT manually

# %%
img_DFT_manually = fft2d(img)

# %% [markdown]
# ## Inverse DFT scipy

# %%
img_iDFT = ifft2(img_DFT_manually)

# %% [markdown]
# ## Plotting image with DFT manually

# %%
fig, ax = plt.subplots(figsize = (8,6))

ax.imshow(img_iDFT.real, cmap = 'gray')

plt.gca().xaxis.set_major_locator(NullLocator())
plt.gca().yaxis.set_major_locator(NullLocator())

# %% [markdown]
# ## DFT manually

# %%
DFT_manually = fft2d(img)

# %% [markdown]
# ## inverse DFT manually

# %%
img_manually = ifft2d(DFT_manually)

# %% [markdown]
# ## Plotting image manually

# %%
fig, ax = plt.subplots(figsize = (8,6))

ax.imshow(img_manually.real, cmap = 'gray')

plt.gca().xaxis.set_major_locator(NullLocator())
plt.gca().yaxis.set_major_locator(NullLocator())

# %% [markdown]
# # Plotting all images

# %%
fig, axs = plt.subplots(2,2, figsize = (18,13))

axs[0][0].imshow(img, cmap = 'gray')
axs[0][1].imshow(img_iDFT_manually.real, cmap = 'gray')
axs[1][0].imshow(img_iDFT.real, cmap = 'gray')
axs[1][1].imshow(img_manually.real, cmap = 'gray')

titles = [['(a)\n', '(b)\n'], ['(c)\n', '(d)\n']]

for axss, titless in zip(axs,titles):
    for ax, title in zip(axss, titless):
        
        # Set title
        
        ax.set_title(title, fontsize = 24)
        
        # Remove axis
        
        ax.xaxis.set_major_locator(NullLocator())
        ax.yaxis.set_major_locator(NullLocator())
